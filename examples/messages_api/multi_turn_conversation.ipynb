# %% [markdown]
# # Multi-Turn Conversations with Claude

# %% [markdown]
# ### 1. Install dependencies

# %%
# uv-managed venvs ship WITHOUT pip, so `%pip install` fails here.
# Use uv instead, pointed at THIS kernel's interpreter so packages land
# where the kernel actually looks. Idempotent: uv no-ops if already satisfied.
import subprocess, sys

subprocess.run(
    ["uv", "pip", "install", "--python", sys.executable, "anthropic", "python-dotenv"],
    check=True,
)
print("Dependencies ready.")
# Out:
# Dependencies ready.

# %% [markdown]
# ### 2. Load environment variables from .env file

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### 3. Create an API client

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"  # unversioned alias -> current Haiku 4.5 snapshot

# %% [markdown]
# ### 4. Helper functions

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %% [markdown]
# ### 4. Make multiple requests to the API

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define a vector embedding in one sentence.")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence, please.")

# Get the follow-up response with full context
final_answer = chat(messages)

# %% [markdown]
# ### 5. Parse the response

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Define a vector embedding in one sentence.'},
#  {'role': 'assistant',
#   'content': 'A vector embedding is a numerical representation of data (such as text, images, or words) as a list of numbers in a high-dimensional space that captures its semantic meaning and relationships to other data.'},
#  {'role': 'user', 'content': 'Write another sentence, please.'}]

# %%
print(final_answer)
# Out:
# Vector embeddings enable machine learning models to perform mathematical operations and comparisons on non-numerical data by converting it into a format that preserves meaningful patterns and similarities.
