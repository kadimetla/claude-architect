# %% [markdown]
# # Accessing Claude with the Messages API

# %% [markdown]
# ### 1. Install dependencies

# %%
# uv-managed venvs ship WITHOUT pip, so `%pip install` fails here.
# Use uv instead, pointed at THIS kernel's interpreter so packages land
# where the kernel actually looks. Idempotent: uv no-ops if already satisfied.
import subprocess, sys

subprocess.run(
    ["uv", "pip", "install", "--python", sys.executable, "anthropic", "python-dotenv"],
    check=True,
)
print("Dependencies ready.")
# Out:
# Dependencies ready.

# %% [markdown]
# ### 2. Load environment variables from .env file

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### 3. Create an API client

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"  # unversioned alias -> current Haiku 4.5 snapshot

# %% [markdown]
# ### 4. Make a request to the API

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "Who was Alexander Hamilton? Answer in one sentence."
        }
    ]
)

# %% [markdown]
# ### 5. Parse the response

# %%
message
# Out:
# Message(id='msg_011CcnuXAz3XUQQLtarGh7D9', container=None, content=[TextBlock(citations=None, text="Alexander Hamilton was a Founding Father of the United States who served as the first Secretary of the Treasury and played a crucial role in establishing the nation's financial system.", type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=36, server_tool_use=None, service_tier='standard'))

# %%
message.content[0].text
# Out:
# "Alexander Hamilton was a Founding Father of the United States who served as the first Secretary of the Treasury and played a crucial role in establishing the nation's financial system."
